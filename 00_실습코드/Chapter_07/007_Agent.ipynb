# %% [markdown]
# # 7장 스스로 판단하고 행동하는 AI 요원, 에이전트
#
# ### 7.1.1 가장 단순한 도구 만들기
#
# ### 필요 패키지 설치
# - 아래 코드 셀을 실행하여 필요한 패키지를 설치합니다.

# %%
# !pip install -U langchain langchain_core langchain_openai langchain_community

# %%
# !pip show langchain

# %% [markdown]
# #### 도구 정의
# - 단순한 형태의 함수를 하나 정의하고, `tool` 데코레이터 부착
# - docstring을 추가

# %% [markdown]
# ### 7.1.2 도구 메타데이터 다듬기
# #### 도구에 상세한 이름 부여하기
# - `tool` 데코레이터에 이름 인자 전달

# %% [markdown]
# #### 도구에 설명 추가하기
# - tool 데코레이터의 description 인자로 도구 설명 전달

# %% [markdown]
# ### 7.1.3 Pydantic 스키마로 구조화된 입력 받기
# #### Pydantic 라이브러리
# - BaseModel을 상속한 클래스로 데이터의 구조schema를 정의

# %% [markdown]
# #### 도구에서 구조화된 데이터 입력받기
# - 도구에서 입력 받을 데이터를 Pydantic으로 구조화시켜 받을 수 있도록 합니다.

# %% [markdown]
# ## 7.2 에이전트 첫걸음
# ### 7.2.1 단일 에이전트 생성하기
# ####	오픈AI API Key 등록

# %%
import os
# Colab 환경 변수에 API 키 저장
os.environ["OPENAI_API_KEY"] = "오픈AI API Key"

# %% [markdown]
# ####	모델 지정과 에이전트 생성

# %% [markdown]
# ####	에이전트 실행하기

# %% [markdown]
# ### 7.2.2 도구를 활용하는 에이전트 생성하기
# ####	도구를 포함한 에이전트 생성하기

# %% [markdown]
# ####	에이전트 실행하기
# - 수학 계산 질문

# %% [markdown]
# - 미국의 온도 단위를 묻는 질문

# %% [markdown]
# #### 랭체인이란 무엇인가를 묻는 질문

# %% [markdown]
# ## 7.3 ReAct 패턴 이해하기
#
# ### 7.3.2 ReAct 과정 관찰하기
# #### YAPF 패키지 설치

# %%
# !pip install yapf

# %% [markdown]
# #### 스타일 설정
#
# - 기본값
#
# ```markdown
# [style]
# based_on_style = pep8
# spaces_before_comment = 4
# split_before_logical_operator = true
# ```

# %%
from yapf.yapflib.yapf_api import FormatCode
style = { 'COLUMN_LIMIT': 50}

# %% [markdown]
# #### stream 메서드

# %% [markdown]
# #### stream 메서드 출력 정리

# %% [markdown]
# ## 7.4 외부 도구 사용하기
# ### 7.4.1 YouTubeSearchTool
# #### 패키지 설치

# %%
# !pip install -U youtube_search

# %% [markdown]
# #### 도구 준비

# %% [markdown]
# #### 에이전트 준비

# %% [markdown]
# #### 답변 생성
